# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
marketing = pd.read_csv('DirectMarketing.csv')

# %%
train_indices, test_indices = train_test_split(np.array(marketing.index), test_size=0.2, random_state=0)

marketing_train = marketing.loc[train_indices].copy()
marketing_test = marketing.loc[test_indices].copy()

# %%
marketing_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 687 to 684
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          800 non-null    object
#  1   Gender       800 non-null    object
#  2   OwnHome      800 non-null    object
#  3   Married      800 non-null    object
#  4   Location     800 non-null    object
#  5   Salary       800 non-null    int64
#  6   Children     800 non-null    int64
#  7   History      558 non-null    object
#  8   Catalogs     800 non-null    int64
#  9   AmountSpent  800 non-null    int64
# dtypes: int64(4), object(6)
# memory usage: 68.8+ KB

# %%
marketing_train.head()
# Out:
#         Age  Gender OwnHome  Married Location  Salary  Children History  \
# 687     Old    Male    Rent  Married    Close   34500         0  Medium
# 500   Young  Female    Rent  Married    Close   79400         0     NaN
# 332  Middle    Male     Own   Single    Close   60300         0     NaN
# 979  Middle  Female     Own  Married    Close   82000         0    High
# 817  Middle  Female     Own  Married      Far   77600         3  Medium
#
#      Catalogs  AmountSpent
# 687        12          802
# 500         6         1175
# 332        24         2091
# 979        18         1800
# 817        12          858

# %%
marketing_dummies = pd.get_dummies(marketing_train)
marketing_dummies.head()
# Out:
#      Salary  Children  Catalogs  AmountSpent  Age_Middle  Age_Old  Age_Young  \
# 687   34500         0        12          802           0        1          0
# 500   79400         0         6         1175           0        0          1
# 332   60300         0        24         2091           1        0          0
# 979   82000         0        18         1800           1        0          0
# 817   77600         3        12          858           1        0          0
#
#      Gender_Female  Gender_Male  OwnHome_Own  OwnHome_Rent  Married_Married  \
# 687              0            1            0             1                1
# 500              1            0            0             1                1
# 332              0            1            1             0                0
# 979              1            0            1             0                1
# 817              1            0            1             0                1
#
#      Married_Single  Location_Close  Location_Far  History_High  History_Low  \
# 687               0               1             0             0            0
# 500               0               1             0             0            0
# 332               1               1             0             0            0
# 979               0               1             0             1            0
# 817               0               0             1             0            0
#
#      History_Medium
# 687               1
# 500               0
# 332               0
# 979               0
# 817               1

# %%
marketing_dummies.corr()['AmountSpent'].sort_values(ascending=False)
# Out:
# AmountSpent        1.000000
# Salary             0.699973
# History_High       0.580216
# Married_Married    0.484576
# Catalogs           0.459767
# OwnHome_Own        0.370616
# Age_Middle         0.321491
# Location_Far       0.242826
# Gender_Male        0.181693
# Age_Old            0.103498
# History_Medium    -0.127086
# Gender_Female     -0.181693
# Children          -0.228622
# Location_Close    -0.242826
# OwnHome_Rent      -0.370616
# Age_Young         -0.445200
# Married_Single    -0.484576
# History_Low       -0.498353
# Name: AmountSpent, dtype: float64

# %%
marketing_train.groupby('History')['AmountSpent'].describe().reindex(['High', 'Medium', 'Low']).round(1)
# Out:
#          count    mean    std    min     25%     50%     75%     max
# History
# High     199.0  2103.9  877.3  565.0  1512.5  1931.0  2530.5  5830.0
# Medium   174.0   960.1  327.9  438.0   705.8   908.0  1159.0  2090.0
# Low      185.0   349.0  207.7   38.0   202.0   292.0   457.0  1120.0

# %%
marketing_train.groupby('History')['AmountSpent'].describe()
# Out:
#          count         mean         std    min      25%     50%     75%  \
# History
# High     199.0  2103.914573  877.309188  565.0  1512.50  1931.0  2530.5
# Low      185.0   348.989189  207.653348   38.0   202.00   292.0   457.0
# Medium   174.0   960.143678  327.947227  438.0   705.75   908.0  1159.0
#
#             max
# History
# High     5830.0
# Low      1120.0
# Medium   2090.0

# %%
marketing_train["History"].unique()
# Out:
# array(['Medium', nan, 'High', 'Low'], dtype=object)

# %%
group = marketing_train.loc[marketing_train["History"] == "High", "AmountSpent"]

# %%
group.mean()
# Out:
# 2103.9145728643216

# %%
marketing_train.groupby('Married')['AmountSpent'].describe().round(1)
# Out:
#          count    mean    std   min    25%     50%     75%     max
# Married
# Married  388.0  1638.0  977.3  93.0  858.0  1512.0  2234.2  5830.0
# Single   412.0   750.3  590.7  38.0  303.0   576.0  1009.8  4182.0

# %%
marketing_train["Married"].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
# Make figure wider to fit both boxplots
plt.figure(figsize=(10, 5))
plt.suptitle('Distribution of History and Marriage Status')

# Create history boxplot
plt.subplot(121) # plt.subplot(1, 2, 1)

history_data = [marketing_train[marketing_train['History'] == 'Low']['AmountSpent'],
                marketing_train[marketing_train['History'] == 'Medium']['AmountSpent'],
                marketing_train[marketing_train['History'] == 'High']['AmountSpent'],
                marketing_train[marketing_train['History'].isna()]['AmountSpent']]
plt.boxplot(history_data)
plt.ylabel('Amount Spent ($)')
plt.xlabel('History')
plt.xticks(range(1, 5), ['Low', 'Medium', 'High', 'None'])
plt.ylim(bottom=0)

# Create married boxplot
plt.subplot(122)  # plt.subplot(1, 2, 2)
married_data = [marketing_train[marketing_train['Married'] == 'Single']['AmountSpent'],
                marketing_train[marketing_train['Married'] == 'Married']['AmountSpent']]
plt.boxplot(married_data)
plt.xlabel('Marriage Status')
plt.xticks(range(1, 3), ['Single', 'Married'])
plt.ylim(bottom=0)

plt.tight_layout()
plt.show()
# Out:
# /Users/jameschok/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# /Users/jameschok/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
# Amount spent by people with low history
marketing_train.loc[marketing_train['History'] == 'Low', 'AmountSpent'].head()
# Out:
# 620    213
# 518    242
# 940    348
# 113    450
# 158    143
# Name: AmountSpent, dtype: int64

# %%
history_data = [marketing_train.loc[marketing_train['History'] == 'Low', 'AmountSpent'],
                marketing_train.loc[marketing_train['History'] == 'Medium', 'AmountSpent'],
                marketing_train.loc[marketing_train['History'] == 'High', 'AmountSpent'],
                marketing_train.loc[marketing_train['History'].isna(), 'AmountSpent']]

plt.boxplot(history_data)

plt.ylabel('Amount Spent ($)')
plt.xlabel('History')

plt.xticks(range(1, 5), ['Low', 'Medium', 'High', 'None'])

plt.ylim(bottom=0)
# Out:
# /Users/jameschok/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# (0, 6119.6)

# %%
history_data = [marketing_train.loc[marketing_train['Married'] == 'Married', 'AmountSpent'],
                marketing_train.loc[marketing_train['Married'] == 'Single', 'AmountSpent']]

plt.boxplot(history_data)

plt.ylabel('Amount Spent ($)')
plt.xlabel('History')

plt.xticks(range(1, 3), ['Married', 'Single'])

plt.ylim(bottom=0)
# Out:
# /Users/jameschok/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# (0, 6119.6)

# %%
cleaned_train = marketing_train.copy()
cleaned_train["History"] = cleaned_train["History"].fillna("None")

# %%
sns.lmplot(y='AmountSpent', x="Salary", data=cleaned_train, hue='History', 
           scatter_kws={"alpha": 0.2})

# %%
sns.lmplot(y='AmountSpent', x="Salary", data=cleaned_train, hue='Married', scatter_kws={"alpha": 0.2})

# %%
sns.regplot(y='AmountSpent', x="Salary", data=marketing_train, scatter_kws={"alpha": 0.4})

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
x = marketing_train.loc[marketing_train["History"] == "Low", "Salary"]
y = marketing_train.loc[marketing_train["History"] == "Low", "AmountSpent"]
sns.regplot(x=x, y=y, scatter_kws={"alpha": 0.4})
plt.ylim(0, 6000)
plt.title("Low")

plt.subplot(1, 3, 2)
x = marketing_train.loc[marketing_train["History"] == "Medium", "Salary"]
y = marketing_train.loc[marketing_train["History"] == "Medium", "AmountSpent"]
sns.regplot(x=x, y=y, scatter_kws={"alpha": 0.4})
plt.ylim(0, 6000)
plt.title("Medium")

plt.subplot(1, 3, 3)
x = marketing_train.loc[marketing_train["History"] == "High", "Salary"]
y = marketing_train.loc[marketing_train["History"] == "High", "AmountSpent"]
sns.regplot(x=x, y=y, scatter_kws={"alpha": 0.4})
plt.ylim(0, 6000)
plt.title("High")
# Out:
# Text(0.5, 1.0, 'High')

# %%
plt.title('Amount Spent Split by History')
history_y = [marketing_train[marketing_train['History'].isna()]['AmountSpent'],
             marketing_train[marketing_train['History'] == 'Low']['AmountSpent'],
             marketing_train[marketing_train['History'] == 'Medium']['AmountSpent'],
             marketing_train[marketing_train['History'] == 'High']['AmountSpent']]

history_x = [marketing_train[marketing_train['History'].isna()]['Salary'],
             marketing_train[marketing_train['History'] == 'Low']['Salary'],
             marketing_train[marketing_train['History'] == 'Medium']['Salary'],
             marketing_train[marketing_train['History'] == 'High']['Salary']]
labels = ['None', 'Low', 'Medium', 'High']

for i in range(len(history_y)):
    plt.scatter(history_x[i], history_y[i], alpha=0.2, label=labels[i])
    
    # This performs polynomial regression - b0 + b1*X + b2*X^2 + b3*X^3 + ...
    coefs = np.polyfit(history_x[i], history_y[i], 1)
    p = np.poly1d(coefs)
    
    plt.plot(marketing_train['Salary'], p(marketing_train['Salary']))

plt.xlabel('Salary ($)')
plt.ylim(bottom=0)
plt.legend(title='History')
plt.xticks(range(0, int(200e3), int(25e3)), ['{}k'.format(i) for i in range(0, 200, 25)]);

# %%
marketing = pd.read_csv("DirectMarketing.csv")
marketing = marketing.loc[:, ["AmountSpent", "Salary", "History"]]

marketing.head()
# Out:
#    AmountSpent  Salary History
# 0          755   47500    High
# 1         1318   63600    High
# 2          296   13500     Low
# 3         2436   85600    High
# 4         1304   68400    High

# %%
marketing_with_dummies = pd.get_dummies(marketing, dummy_na=True, drop_first=True)
marketing_with_dummies.head()
# Out:
#    AmountSpent  Salary  History_Low  History_Medium  History_nan
# 0          755   47500            0               0            0
# 1         1318   63600            0               0            0
# 2          296   13500            1               0            0
# 3         2436   85600            0               0            0
# 4         1304   68400            0               0            0

# %%
train_indices, test_indices = train_test_split(np.array(marketing_with_dummies.index), 
                                               test_size=0.2, random_state=0)

marketing_train = marketing_with_dummies.loc[train_indices].copy()
marketing_test = marketing_with_dummies.loc[test_indices].copy()

# %%
marketing_train.head()
# Out:
#      AmountSpent  Salary  History_Low  History_Medium  History_nan
# 687          802   34500            0               1            0
# 500         1175   79400            0               0            1
# 332         2091   60300            0               0            1
# 979         1800   82000            0               0            0
# 817          858   77600            0               1            0

# %%
import statsmodels.api as sm

# %%
y_train = np.log(marketing_train["AmountSpent"])
x_train = marketing_train.drop(columns="AmountSpent")
x_train = sm.add_constant(x_train)

# %%
model = sm.OLS(y_train, x_train).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            AmountSpent   R-squared:                       0.696
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     454.3
# Date:                Tue, 08 Mar 2022   Prob (F-statistic):          1.20e-203
# Time:                        15:55:35   Log-Likelihood:                -556.01
# No. Observations:                 800   AIC:                             1122.
# Df Residuals:                     795   BIC:                             1145.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              6.4894      0.067     97.480      0.000       6.359       6.620
# Salary          1.294e-05   6.82e-07     18.955      0.000    1.16e-05    1.43e-05
# History_Low       -1.2226      0.061    -20.148      0.000      -1.342      -1.104
# History_Medium    -0.3907      0.054     -7.228      0.000      -0.497      -0.285
# History_nan       -0.3274      0.052     -6.350      0.000      -0.429      -0.226
# ==============================================================================
# Omnibus:                       16.438   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.882
# Skew:                          -0.342   Prob(JB):                     0.000216
# Kurtosis:                       3.198   Cond. No.                     3.77e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
fitted_values = model.fittedvalues
residuals = model.resid

# %%
y_train - fitted_values
# Out:
# 687    0.142189
# 500   -0.119992
# 332    0.703457
# 979   -0.054546
# 817   -0.347850
#          ...
# 835   -0.050987
# 192    0.441413
# 629    0.284856
# 559   -0.329854
# 684    0.555728
# Length: 800, dtype: float64

# %%
plt.scatter(fitted_values, residuals)
plt.xlabel("Fitted Values (Model Predictions)")
plt.ylabel("Residuals");

# %% [markdown]
# $$\large Y = f(x) + \varepsilon$$
#
# Importantly $\varepsilon$ is random
#
# $$\large Y - f(x) = \varepsilon$$

# %%
plt.scatter(marketing_train["Salary"], marketing_train["AmountSpent"])

# %%
plt.scatter(marketing_train["Salary"], np.log(marketing_train["AmountSpent"]))

# %%
plt.scatter(np.log(marketing_train["Salary"]), np.log(marketing_train["AmountSpent"]))

# %%
sns.regplot(x=np.log(marketing_train["Salary"]), y=np.log(marketing_train["AmountSpent"]), 
            scatter_kws={"alpha": 0.2})

# %%
marketing = pd.read_csv("DirectMarketing.csv")
marketing = marketing.loc[:, ["AmountSpent", "Salary", "History"]]

marketing["log-salary"] = np.log(marketing["Salary"])
marketing = marketing.drop(columns="Salary")

marketing["log-AmountSpent"] = np.log(marketing["AmountSpent"])
marketing = marketing.drop(columns="AmountSpent")

# Get Dummy Variables
marketing = pd.get_dummies(marketing, dummy_na=True, drop_first=True)

# Create Interaction Variable
marketing["History_Medium * log-salary"] = marketing["log-salary"] * marketing["History_Medium"]
marketing["History_nan * log-salary"] = marketing["log-salary"] * marketing["History_nan"]

# %%
train_indices, test_indices = train_test_split(np.array(marketing.index), 
                                               test_size=0.2, random_state=0)

marketing_train = marketing.loc[train_indices].copy()
marketing_test = marketing.loc[test_indices].copy()

# %%
y_train = marketing_train["log-AmountSpent"]
x_train = marketing_train.drop(columns="log-AmountSpent")
x_train = sm.add_constant(x_train)

# %%
model = sm.OLS(y_train, x_train).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log-AmountSpent   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     451.5
# Date:                Tue, 08 Mar 2022   Prob (F-statistic):          8.42e-252
# Time:                        16:14:47   Log-Likelihood:                -437.76
# No. Observations:                 800   AIC:                             889.5
# Df Residuals:                     793   BIC:                             922.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           3.2584      0.514      6.336      0.000       2.249       4.268
# log-salary                      0.3816      0.045      8.395      0.000       0.292       0.471
# History_Low                    -1.4546      0.067    -21.809      0.000      -1.585      -1.324
# History_Medium                  1.9871      1.111      1.789      0.074      -0.194       4.168
# History_nan                    -7.2684      0.661    -10.990      0.000      -8.567      -5.970
# History_Medium * log-salary    -0.2373      0.101     -2.339      0.020      -0.436      -0.038
# History_nan * log-salary        0.6377      0.060     10.642      0.000       0.520       0.755
# ==============================================================================
# Omnibus:                       15.978   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.845
# Skew:                          -0.242   Prob(JB):                     4.91e-05
# Kurtosis:                       3.601   Cond. No.                         933.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.scatter(model.fittedvalues, model.resid);
